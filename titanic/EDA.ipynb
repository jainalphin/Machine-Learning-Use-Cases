# %% [markdown]
# # Titanic

# %% [markdown]
# 1. Passenger Id- Id number of passenger in data set
# 2. Name- Name of the passenger
# 3. Survival- Person survived or not ( 0 for No & 1 for Yes)
# 4. Pclass- With what class of ticket that passenger was travelling.
# 5. sex- Male Or Female
# 6. Age- Age of the person in Years
# 7. Sibsp- Number of siblings / spouses on the Titanic
# 8. parch- Number of parents / children on the Titanic
# 9. Ticket- Ticket number
# 10. Fare- Amount of money that person paid to travel
# 11. Cabin- Cabin Number of Passenger
# 12. Embarked- Port of Embarkation ( C = Cherbourg, Q = Queenstown, S = Southampton)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
train=  pd.read_csv("train.csv")
df= train.copy()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.pairplot(df[['Survived','Pclass','Fare','Age']],hue='Survived')

# %% [markdown]
# ## Survival Feature

# %%
total = len(df['Survived'])
splot=sns.countplot(df['Survived'],data=df)
for p in splot.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2.
    y =p.get_height()
    splot.annotate(percentage, (x, y), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

# %% [markdown]
#  1. more than 500 passengers died in the disaster
#  2. approx 350 people survived

# %% [markdown]
# ## Sex Feature

# %%
total =len(df['Sex'])
splot =sns.countplot('Sex',hue='Survived',data=df)
for p in splot.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2.
    y =p.get_height()
    splot.annotate(percentage, (x, y), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
    
plt.title('Sex vs Survived')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6fa32ec6964b> in <module>
# ----> 1 total =len(df['Sex'])
#       2 splot =sns.countplot('Sex',hue='Survived',data=df)
#       3 for p in splot.patches:
#       4     percentage = '{:.2f}%'.format(100 * p.get_height()/total)
#       5     x = p.get_x() + p.get_width() / 2.
#
# NameError: name 'df' is not defined

# %% [markdown]
# 1. Out of all male passengers mostly of them died
# 2. Out of all Female passengers most of them survived

# %% [markdown]
# # Pclass Feature

# %%
splot = sns.countplot('Pclass',hue='Survived',data=df)

for p in splot.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2.
    y =p.get_height()
    splot.annotate(percentage, (x, y), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.title('Plcass vs Survived')
# Out:
# Text(0.5, 1.0, 'Plcass vs Survived')

# %% [markdown]
# 1. Passengers who were travelling in 3rd class ,mostly of them died or can not survived than other class passengers.
# 2. Passengers who were travelling in 2nd class, out of them almost equal number of people died and survived.
# 3. Passengers who were travelling in 1st class, out of them large number of people survived and also fair number of persons died.

# %% [markdown]
# ## Age Feature

# %%
#distibution of data
sns.FacetGrid(df.fillna(df['Age'].median()), hue="Survived",size=6).map(sns.distplot, "Age").add_legend()
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 1. passenges age less than 20 were survived the most
# 2. passengers age between 20 and 40 were died the most

# %% [markdown]
# ## SibSp Feature

# %%
plt.figure(figsize=(12,4))
splot=sns.countplot('SibSp',hue='Survived',data=df)
for p in splot.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/len(df['SibSp']))
    x = p.get_x() + p.get_width() / 2.
    y =p.get_height()
    splot.annotate(percentage, (x, y), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.legend(loc=(0.75,0.75),fontsize='large')

# %% [markdown]
# 1. Passegner who have 0 sibling died the most
# 2. Passengers with 1 sibling has equally chance for both die and survive.
# 3. passengers who have higher number of siblings like 3 , 4 , 5, 8 has a very low chance to survive or almost 0% chance to    survive.

# %% [markdown]
# ## Parch Feature

# %%
plt.figure(figsize=(12,4))
splot=sns.countplot('Parch',hue='Survived',data=df)
for p in splot.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/len(df['Parch']))
    x = p.get_x() + p.get_width() / 2.
    y =p.get_height()
    splot.annotate(percentage, (x, y), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')
plt.legend(loc=(0.75,0.75),fontsize='large')

# %% [markdown]
# 1. Same as Sibling/Spouse in Parch -parents and childern, passenger who was single died the most
# 2. Passengers who in  1 or 2 Parch category has equally chance for both die and survive.

# %% [markdown]
# ## Fare Feature

# %%
sns.FacetGrid(df,hue='Survived',size=6).map(sns.distplot,'Fare')

# %% [markdown]
# 1. Passenger who paid low fair has higher chance to die
# 2. Passenger who paid higer salary has higher chance tio survive

# %% [markdown]
# ## Embarked Feature

# %%
splot= sns.countplot('Embarked',hue='Survived',data=df)
for p in splot.patches:
    percentage = "{:.1f}%".format(100 * p.get_height()/len(df['Embarked']))
    x=p.get_x() +p.get_width()/2
    y=p.get_height()
    splot.annotate(percentage,(x,y),ha='center',va='center',xytext=(0,10),textcoords='offset points')

# %% [markdown]
# 1. Passengers who started his journey from Southampton , most of them died.
# 2. There is not any much difference in peoples surviving or die chances who started his journey from Cherbourg , Queenstown
